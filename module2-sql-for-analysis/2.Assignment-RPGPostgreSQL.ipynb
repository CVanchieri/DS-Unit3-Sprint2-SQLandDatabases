# %%
# pip installs.
# !pip install psycopg2-binary
# Out:
# ...
#      |████████████████████████████████| 2.9MB 9.8MB/s
# ...

# %%
# imports.
import sqlite3

# %%
# queries.
q1 = 'SELECT COUNT(character_id) \
          FROM charactercreator_character'

# create connection to file.
conn = sqlite3.connect('rpg_db.sqlite3')
# create cursor.
curs = conn.cursor()
# print q1 with execute.
print('Total # of characters =', curs.execute(q1).fetchall())
# Out:
# Total # of characters = [(302,)]

# %%
# close cursors.
curs.close()
# commit.
conn.commit()

# %% [markdown]
# ### Insert the RPG Data Into PostgreSQL.

# %%
# imports.
import pandas as pd
from sqlalchemy import create_engine
import psycopg2

# %%
# create connection to file.
conn2 =sqlite3.connect('rpg_db.sqlite3')
#create cursor.
cur2 = conn2.cursor()

# %%
# test connection.
cur2.execute('SELECT * FROM charactercreator_character')
# create table.
character_table = cur2.fetchall()
# show 1st row of table.
character_table[0]
# Out:
# (1, 'Aliquid iste optio reiciendi', 0, 0, 10, 1, 1, 1, 1)

# %%
# set the postgress connection.
db_string = 'postgres://xwctuzax:Stxqux7UfKeCsPGsJEOU4YuRUR38vmYy@raja.db.elephantsql.com:5432/xwctuzax'
# create the engine.
engine = create_engine(db_string)

# %%
# connect to the engine.
conn3 = engine.connect()

# %%
# change charactercreator_character to df.
df = pd.read_sql('SELECT * FROM charactercreator_character', conn2)
df
# Out:
#      character_id                            name  ...  dexterity  wisdom
# 0               1    Aliquid iste optio reiciendi  ...          1       1
# 1               2              Optio dolorem ex a  ...          1       1
# 2               3                         Minus c  ...          1       1
# 3               4                     Sit ut repr  ...          1       1
# 4               5           At id recusandae expl  ...          1       1
# ..            ...                             ...  ...        ...     ...
# 297           298    Autem ratione vitae quos, do  ...          1       1
# 298           299            Voluptatibus aliquid  ...          1       1
# 299           300  Quaerat sequi sit eius corpori  ...          1       1
# 300           301                            Libe  ...          1       1
# 301           302                       Aliquam n  ...          1       1
#
# [302 rows x 9 columns]

# %%
# store the df in postgress.
table_names_dict = {'charactercreator_character': 'character_id'}
# for loop to create the table.
for table_name, primary_key in table_names_dict.items():
  df = pd.read_sql(f"SELECT * FROM {table_name}", conn2)
  df = df.set_index(primary_key, verify_integrity=True)
  df.to_sql(table_name, conn3)

# %%
# close cursor.
cur2.close()
# commit.
conn2.commit()
